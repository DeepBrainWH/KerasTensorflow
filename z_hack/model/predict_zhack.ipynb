# %%
import tensorflow as tf
from tensorflow.python.keras.layers import Dense, Dropout, CuDNNLSTM, RNN, GRU
from tensorflow.python.keras.models import Sequential
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
file_name = "../data/all_part"
dataframe = pd.read_csv(file_name, sep="\t")
all_data = dataframe.iloc[:, -1].values

TIMESTEP = 20
TRAINING_STEPS = 10000

# %%
dataframe.iloc[:10, -1]
# Out:
# 0    2824.303102
# 1    2823.491818
# 2    2798.935017
# 3    2811.224173
# 4    2782.819729
# 5    2791.764161
# 6    2849.966686
# 7    2848.203796
# 8    2904.523836
# 9    2945.673332
# Name: 日均成交金额, dtype: float64

# %%
my_iloc = dataframe.iloc[:10, :]

# %%
type(my_iloc)
# Out:
# pandas.core.frame.DataFrame

# %%
my_iloc
# Out:
#            日期        总成交金额   总成交数量       日均成交金额
# 0  2009-01-04  161674229.0  460360  2824.303102
# 1  2009-01-05  141471095.0  419527  2823.491818
# 2  2009-01-06   84491048.0  206177  2798.935017
# 3  2009-01-07  113116729.0  332283  2811.224173
# 4  2009-01-08   86225458.0  220036  2782.819729
# 5  2009-01-09   96528746.0  212408  2791.764161
# 6  2009-01-12  188201601.0  634212  2849.966686
# 7  2009-01-13  121582221.0  339050  2848.203796
# 8  2009-01-14  166679271.0  555477  2904.523836
# 9  2009-01-15   82333494.0  226080  2945.673332

# %%
my_iloc.iloc[:, -1]
# Out:
# 0    2824.303102
# 1    2823.491818
# 2    2798.935017
# 3    2811.224173
# 4    2782.819729
# 5    2791.764161
# 6    2849.966686
# 7    2848.203796
# 8    2904.523836
# 9    2945.673332
# Name: 日均成交金额, dtype: float64

# %%
all_data[:10]
# Out:
# array([2824.30310192, 2823.49181817, 2798.935017  , 2811.22417337,
#        2782.8197295 , 2791.76416143, 2849.96668622, 2848.2037959 ,
#        2904.52383627, 2945.67333245])

# %%
def get_train_data(data):
    x_train = []
    y_train = []
    for i in range(int(data.shape[0]) - TIMESTEP):
        x_train.append(data[i:i+TIMESTEP])
        y_train.append(data[i+TIMESTEP])
    
    x_train = np.asarray(x_train, dtype=np.float32)
    y_train = np.asarray(y_train, dtype=np.float32)
    
    return x_train, y_train

# %%
all_data.shape
# Out:
# (1237,)

# %%
x_train, y_train = get_train_data(all_data)

# %%
x_train.shape
# Out:
# (1217, 20)

# %%
y_train.shape
# Out:
# (1217,)

# %%
y_train
# Out:
# array([3064.9817, 3102.72  , 3186.4844, ..., 4852.81  , 4839.5396,
#        4790.2197], dtype=float32)

# %%
x_train[-1, :]
# Out:
# array([5025.9683, 4972.524 , 4957.9785, 4946.451 , 4942.276 , 4943.7124,
#        4899.281 , 4876.277 , 4886.4536, 4864.443 , 4866.7417, 4885.6543,
#        4871.8047, 4899.712 , 4882.1436, 4856.293 , 4856.8867, 4857.1865,
#        4852.81  , 4839.5396], dtype=float32)

# %%
all_data[-11:]
# Out:
# array([4866.74146842, 4885.65448047, 4871.80489065, 4899.71173763,
#        4882.14366783, 4856.2928841 , 4856.88675121, 4857.18665862,
#        4852.81022045, 4839.53964182, 4790.21956024])

# %%
mean = np.mean(all_data)

# %%
mean
# Out:
# 5583.9755377124

# %%
all_data.min()
# Out:
# 2782.819729498809

# %%
all_data.max()
# Out:
# 7703.43333325265

# %%
normalize_all_data = (all_data - all_data.min()) / (all_data.max() - all_data.min())

# %%
normalize_all_data.max()
# Out:
# 1.0

# %%
normalize_all_data[:10]
# Out:
# array([0.00843053, 0.00826565, 0.00327506, 0.00577254, 0.        ,
#        0.00181775, 0.01364605, 0.01328779, 0.02473352, 0.0330962 ])

# %%
np.save("normalize_data.npy", normalize_all_data)

# %%
load_data = np.load("normalize_data.npy")
load_data[:10]
# Out:
# array([0.00843053, 0.00826565, 0.00327506, 0.00577254, 0.        ,
#        0.00181775, 0.01364605, 0.01328779, 0.02473352, 0.0330962 ])

# %%
x_train, y_train = get_train_data(load_data)

# %%
x_train.shape
print(y_train.shape)
# Out:
# (1217,)

# %%
plt.figure(figsize=(20, 10))
plt.plot(y_train)
plt.plot(x_train[:, -1])
plt.show()

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)

# %%
x_train.shape
# Out:
# (1217, 20, 1)

# %%
model = Sequential()
model.add(CuDNNLSTM(50, input_shape=(None, 1), return_sequences=True))
model.add(Dropout(0.2))
model.add(CuDNNLSTM(100, return_sequences=True))
model.add(Dropout(0.4))
model.add(CuDNNLSTM(100))
model.add(Dropout(0.2))
model.add(Dense(50, activation='tanh'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mae", optimizer="adam", metrics=['mae'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_6 (CuDNNLSTM)     (None, None, 50)          10600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, 50)          0
# _________________________________________________________________
# cu_dnnlstm_7 (CuDNNLSTM)     (None, None, 100)         60800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# cu_dnnlstm_8 (CuDNNLSTM)     (None, 100)               80800
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 158,291
# Trainable params: 158,291
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_train.shape
# Out:
# (1217, 20, 1)

# %%
y_train = y_train.reshape(y_train.shape[0], 1)
y_train.shape
# Out:
# (1217, 1)

# %%
history = model.fit(x_train, y_train, epochs=1000, batch_size=50, verbose=0, validation_split=0.2)

# %%
history1 = model.fit(x_train, y_train, validation_split=0.25, epochs=50, batch_size=50, verbose=1)
# Out:
# Train on 912 samples, validate on 305 samples
# Epoch 1/50
# 912/912 [==============================] - 0s 226us/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0107 - val_mean_absolute_error: 0.0107
# Epoch 2/50
# 912/912 [==============================] - 0s 216us/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097
# Epoch 3/50
# 912/912 [==============================] - 0s 221us/step - loss: 0.0140 - mean_absolute_error: 0.0140 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078
# Epoch 4/50
# 912/912 [==============================] - 0s 232us/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0080 - val_mean_absolute_error: 0.0080
# Epoch 5/50
# 912/912 [==============================] - 0s 225us/step - loss: 0.0145 - mean_absolute_error: 0.0145 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086
# Epoch 6/50
# 912/912 [==============================] - 0s 226us/step - loss: 0.0138 - mean_absolute_error: 0.0138 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 7/50
# 912/912 [==============================] - 0s 225us/step - loss: 0.0139 - mean_absolute_error: 0.0139 - val_loss: 0.0073 - val_mean_absolute_error: 0.0073
# Epoch 8/50
# 912/912 [==============================] - 0s 227us/step - loss: 0.0127 - mean_absolute_error: 0.0127 - val_loss: 0.0071 - val_mean_absolute_error: 0.0071
# Epoch 9/50
# 912/912 [==============================] - 0s 226us/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 10/50
# 912/912 [==============================] - 0s 224us/step - loss: 0.0133 - mean_absolute_error: 0.0133 - val_loss: 0.0072 - val_mean_absolute_error: 0.0
# Epoch 33/50
# 912/912 [==============================] - 0s 230us/step - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0119 - val_mean_absolute_error: 0.0119
# Epoch 34/50
# 912/912 [==============================] - 0s 227us/step - loss: 0.0146 - mean_absolute_error: 0.0146 - val_loss: 0.0087 - val_mean_absolute_error: 0.0087
# Epoch 35/50
# 912/912 [==============================] - 0s 229us/step - loss: 0.0135 - mean_absolute_error: 0.0135 - val_loss: 0.0076 - val_mean_absolute_error: 0.0076
# Epoch 36/50
# 912/912 [==============================] - 0s 217us/step - loss: 0.0132 - mean_absolute_error: 0.0132 - val_loss: 0.0084 - val_mean_absolute_error: 0.0084
# Epoch 37/50
# 912/912 [==============================] - 0s 228us/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0078 - val_mean_absolute_error: 0.0078
# Epoch 38/50
# 912/912 [==============================] - 0s 232us/step - loss: 0.0129 - mean_absolute_error: 0.0129 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 39/50
# 912/912 [==============================] - 0s 234us/step - loss: 0.0144 - mean_absolute_error: 0.0144 - val_loss: 0.0096 - val_mean_absolute_error: 0.0096
# Epoch 40/50
# 912/912 [==============================] - 0s 227us/step - loss: 0.0137 - mean_absolute_error: 0.0137 - val_loss: 0.0083 - val_mean_absolute_error: 0.0083
# Epoch 41/50
# 912/912 [==============================] - 0s 232us/step - loss: 0.0153 - mean_absolute_error: 0.0153 - val_loss: 0.0085 - val_mean_absolute_error: 0.0085
# Epoch 42/50
# 912/912 [==============================] - 0s 241us/step - loss: 0.0160 - mean_absolute_error: 0.0160 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098
# Epoch 43/50
# 912/912 [==============================] - 0s 227us/step - loss: 0.0155 - mean_absolute_error: 0.0155 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099
# Epoch 44/50
# 912/912 [==============================] - 0s 220us/step - loss: 0.0131 - mean_absolute_error: 0.0131 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 45/50
# 912/912 [==============================] - 0s 233us/step - loss: 0.0136 - mean_absolute_error: 0.0136 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 46/50
# 912/912 [==============================] - 0s 236us/step - loss: 0.0143 - mean_absolute_error: 0.0143 - val_loss: 0.0113 - val_mean_absolute_error: 0.0113
# Epoch 47/50
# 912/912 [==============================] - 0s 233us/step - loss: 0.0168 - mean_absolute_error: 0.0168 - val_loss: 0.0113 - val_mean_absolute_error: 0.0113
# Epoch 48/50
# 912/912 [==============================] - 0s 229us/step - loss: 0.0148 - mean_absolute_error: 0.0148 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099
# Epoch 49/50
# 912/912 [==============================] - 0s 227us/step - loss: 0.0141 - mean_absolute_error: 0.0141 - val_loss: 0.0079 - val_mean_absolute_error: 0.0079
# Epoch 50/50
# 912/912 [==============================] - 0s 223us/step - loss: 0.0152 - mean_absolute_error: 0.0152 - val_loss: 0.0105 - val_mean_absolute_error: 0.0105

# %%
print(history1.history)
# Out:
history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('abs_loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
val_loss = np.asarray(history.history['val_loss'], dtype=np.float32)
val_loss.shape
# Out:
# (1000,)

# %%
df = pd.DataFrame(np.sqrt(val_loss))
df.to_csv('wangheng_model1.csv', mode='w', header=False)

# %%
model.save('origional_wangheng_model.h5')

# %%
from tensorflow.python.keras.models import load_model
loadmymodel = load_model('./origional_wangheng_model.h5')

# %%
history2 = loadmymodel.fit(x_train, y_train, validation_split=0.25, epochs=1000, batch_size=50, verbose=0)

# %%
loadmymodel.save('origional_wangheng_model.h5')

# %%
val_loss = np.asarray(history2.history['val_loss'], dtype=np.float32)
print(val_loss.shape)
df = pd.DataFrame(val_loss)
df.to_csv('wangheng_model1.csv', mode='a', header=False)
# Out:
# (1000,)

# %%
df2 = pd.read_csv("./wangheng_model1.csv")
val_loss_2 = df2.iloc[:, -1].values

# %%
plt.figure(figsize=(20, 10))
plt.plot(val_loss_2)
plt.title('Model accuracy')
plt.ylabel('abs_loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
model2 = Sequential()
model2.add(CuDNNLSTM(50, input_shape=(None, 1), return_sequences=True))
model2.add(Dropout(0.2))
model2.add(CuDNNLSTM(100, return_sequences=True))
model2.add(Dropout(0.4))
model2.add(CuDNNLSTM(100))
model2.add(Dropout(0.2))
model2.add(Dense(50, activation='tanh'))
model2.add(Dense(20, activation='tanh'))
model2.add(Dense(1, activation='linear'))
model2.compile(loss="mse", optimizer="adam", metrics=['acc', 'mae'])
print(model2.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_12 (CuDNNLSTM)    (None, None, 50)          10600
# _________________________________________________________________
# dropout_12 (Dropout)         (None, None, 50)          0
# _________________________________________________________________
# cu_dnnlstm_13 (CuDNNLSTM)    (None, None, 100)         60800
# _________________________________________________________________
# dropout_13 (Dropout)         (None, None, 100)         0
# _________________________________________________________________
# cu_dnnlstm_14 (CuDNNLSTM)    (None, 100)               80800
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 158,291
# Trainable params: 158,291
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history2 = model2.fit(x_train, y_train, validation_split=0.25, epochs=3000, batch_size=20, verbose=0)

# %%
plt.figure(figsize=(20, 10))
plt.plot(history2.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
model2.save("model2.h5")

# %% [markdown]
# # 再次训练

# %%
from tensorflow.python.keras.models import load_model
model2_sec = load_model("model2.h5")
history2_sec = model2_sec.fit(x_train, y_train, validation_split=0.25, epochs=500, batch_size=20, verbose=0)

# %%
plt.figure(figsize=(20, 10))
plt.plot(history2_sec.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.ylim(0.0000, 0.0030)
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(all_history2_loss)
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.ylim(0.0000, 0.0030)
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-7e33b56dbb72> in <module>()
#       1 plt.figure(figsize=(20, 10))
# ----> 2 plt.plot(all_history2_loss)
#       3 plt.title('Model accuracy')
#       4 plt.ylabel('val_loss')
#       5 plt.ylim(0.0000, 0.0030)
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     351         # downstream.
#     352         if any(v is None for v in tup):
# --> 353             raise ValueError("x, y, and format string must not be None")
#     354
#     355         kw = {}
#
# ValueError: x, y, and format string must not be None

# %%
x_train[0, :, :]

# %%
y_train[0, :]

# %%
model.predict(x_train[0, :, :].reshape(1, 20, 1))
