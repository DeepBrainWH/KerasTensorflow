# %%
import tensorflow as tf
from tensorflow.python.keras.layers import Dense, Dropout, CuDNNLSTM, RNN, GRU
from tensorflow.python.keras.models import Sequential
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
file_name = "../data/all_part"
dataframe = pd.read_csv(file_name, sep="\t")
all_data = dataframe.iloc[:, -1].values

TIMESTEP = 20
TRAINING_STEPS = 10000

# %%
dataframe.iloc[:10, -1]
# Out:
# 0    2824.303102
# 1    2823.491818
# 2    2798.935017
# 3    2811.224173
# 4    2782.819729
# 5    2791.764161
# 6    2849.966686
# 7    2848.203796
# 8    2904.523836
# 9    2945.673332
# Name: 日均成交金额, dtype: float64

# %%
my_iloc = dataframe.iloc[:10, :]

# %%
type(my_iloc)
# Out:
# pandas.core.frame.DataFrame

# %%
my_iloc
# Out:
#            日期        总成交金额   总成交数量       日均成交金额
# 0  2009-01-04  161674229.0  460360  2824.303102
# 1  2009-01-05  141471095.0  419527  2823.491818
# 2  2009-01-06   84491048.0  206177  2798.935017
# 3  2009-01-07  113116729.0  332283  2811.224173
# 4  2009-01-08   86225458.0  220036  2782.819729
# 5  2009-01-09   96528746.0  212408  2791.764161
# 6  2009-01-12  188201601.0  634212  2849.966686
# 7  2009-01-13  121582221.0  339050  2848.203796
# 8  2009-01-14  166679271.0  555477  2904.523836
# 9  2009-01-15   82333494.0  226080  2945.673332

# %%
my_iloc.iloc[:, -1]
# Out:
# 0    2824.303102
# 1    2823.491818
# 2    2798.935017
# 3    2811.224173
# 4    2782.819729
# 5    2791.764161
# 6    2849.966686
# 7    2848.203796
# 8    2904.523836
# 9    2945.673332
# Name: 日均成交金额, dtype: float64

# %%
all_data[:10]
# Out:
# array([2824.30310192, 2823.49181817, 2798.935017  , 2811.22417337,
#        2782.8197295 , 2791.76416143, 2849.96668622, 2848.2037959 ,
#        2904.52383627, 2945.67333245])

# %%
def get_train_data(data):
    x_train = []
    y_train = []
    for i in range(int(data.shape[0]) - TIMESTEP):
        x_train.append(data[i:i+TIMESTEP])
        y_train.append(data[i+TIMESTEP])
    
    x_train = np.asarray(x_train, dtype=np.float32)
    y_train = np.asarray(y_train, dtype=np.float32)
    
    return x_train, y_train

# %%
all_data.shape
# Out:
# (1237,)

# %%
x_train, y_train = get_train_data(all_data)

# %%
x_train.shape
# Out:
# (1217, 20)

# %%
y_train.shape
# Out:
# (1217,)

# %%
y_train
# Out:
# array([3064.9817, 3102.72  , 3186.4844, ..., 4852.81  , 4839.5396,
#        4790.2197], dtype=float32)

# %%
x_train[-1, :]
# Out:
# array([5025.9683, 4972.524 , 4957.9785, 4946.451 , 4942.276 , 4943.7124,
#        4899.281 , 4876.277 , 4886.4536, 4864.443 , 4866.7417, 4885.6543,
#        4871.8047, 4899.712 , 4882.1436, 4856.293 , 4856.8867, 4857.1865,
#        4852.81  , 4839.5396], dtype=float32)

# %%
all_data[-11:]
# Out:
# array([4866.74146842, 4885.65448047, 4871.80489065, 4899.71173763,
#        4882.14366783, 4856.2928841 , 4856.88675121, 4857.18665862,
#        4852.81022045, 4839.53964182, 4790.21956024])

# %%
mean = np.mean(all_data)

# %%
mean
# Out:
# 5583.9755377124

# %%
mean_all_data = all_data - mean
print(mean_all_data.max(), mean_all_data.min())
# Out:
# 2119.45779554025 -2801.155808213591

# %%
max = np.abs(all_data).max()

# %%
max
# Out:
# 7703.43333325265

# %%
normalize_all_data = all_data/max

# %%
normalize_all_data.max()
# Out:
# 1.0

# %%
normalize_all_data[:10]
# Out:
# array([0.36662914, 0.36652382, 0.36333605, 0.36493133, 0.36124409,
#        0.36240518, 0.36996058, 0.36973174, 0.37704277, 0.38238448])

# %%
np.save("normalize_data.npy", normalize_all_data)

# %%
load_data = np.load("normalize_data.npy")
load_data[:10]
# Out:
# array([0.36662914, 0.36652382, 0.36333605, 0.36493133, 0.36124409,
#        0.36240518, 0.36996058, 0.36973174, 0.37704277, 0.38238448])

# %%
x_train, y_train = get_train_data(load_data)

# %%
x_train.shape
print(y_train.shape)
# Out:
# (1217,)

# %%
plt.figure(figsize=(20, 10))
plt.plot(y_train)
plt.plot(x_train[:, -1])
plt.show()

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)

# %%
x_train.shape
# Out:
# (1217, 20, 1)

# %%
model = Sequential()
model.add(CuDNNLSTM(50, input_shape=(None, 1), return_sequences=True))
model.add(Dropout(0.2))
model.add(CuDNNLSTM(100, return_sequences=True))
model.add(Dropout(0.4))
model.add(CuDNNLSTM(100))
model.add(Dropout(0.2))
model.add(Dense(50, activation='tanh'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mse", optimizer="adam", metrics=['mae'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm (CuDNNLSTM)       (None, None, 50)          10600
# _________________________________________________________________
# dropout (Dropout)            (None, None, 50)          0
# _________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)     (None, None, 100)         60800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# cu_dnnlstm_2 (CuDNNLSTM)     (None, 100)               80800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 50)                5050
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 158,291
# Trainable params: 158,291
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_train.shape
# Out:
# (1217, 20, 1)

# %%
y_train = y_train.reshape(y_train.shape[0], 1)
y_train.shape
# Out:
# (1217, 1)

# %%
history = model.fit(x_train, y_train, epochs=1000, verbose=0, validation_split=0.2)

# %%
history1 = model.fit(x_train, y_train, validation_split=0.25, epochs=50, batch_size=16, verbose=1)
# Out:
# Train on 912 samples, validate on 305 samples
# Epoch 1/50
# 912/912 [==============================] - 1s 574us/step - loss: 1.3245e-04 - mean_absolute_error: 0.0089 - val_loss: 6.2159e-05 - val_mean_absolute_error: 0.0065
# Epoch 2/50
# 912/912 [==============================] - 1s 552us/step - loss: 1.5283e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3211e-04 - val_mean_absolute_error: 0.0099
# Epoch 3/50
# 912/912 [==============================] - 1s 554us/step - loss: 1.6821e-04 - mean_absolute_error: 0.0102 - val_loss: 4.7286e-05 - val_mean_absolute_error: 0.0055
# Epoch 4/50
# 912/912 [==============================] - 1s 559us/step - loss: 1.9316e-04 - mean_absolute_error: 0.0111 - val_loss: 4.5516e-05 - val_mean_absolute_error: 0.0052
# Epoch 5/50
# 912/912 [==============================] - 1s 555us/step - loss: 1.6945e-04 - mean_absolute_error: 0.0103 - val_loss: 5.7083e-05 - val_mean_absolute_error: 0.0061
# Epoch 6/50
# 912/912 [==============================] - 1s 568us/step - loss: 1.8189e-04 - mean_absolute_error: 0.0105 - val_loss: 4.4069e-05 - val_mean_absolute_error: 0.0052
# Epoch 7/50
# 912/912 [==============================] - 1s 557us/step - loss: 1.6479e-04 - mean_absolute_error: 0.0101 - val_loss: 1.7461e-04 - val_mean_absolute_error: 0.0119
# Epoch 8/50
# 912/912 [==============================] - 1s 567us/step - loss: 1.8074e-04 - mean_absolute_error: 0.0107 - val_loss: 4.4765e-05 - val_mean_absolute_error: 0.0051
# Epoch 9/50
# 912/912 [==============================] - 1s 573us/step - loss: 1.6696e-04 - mean_absolute_error: 0.0102 - val_loss: 6.8705e-05 - val_mean_absolute_error: 0.0069
# Epoch 10/50
# 912/912 [==============================] - 1s 570us/step - loss: 1.8574e-04 - mean_absolute_error: 0.0108 - val_loss: 2.3325e-04 - val_mean_absolute_error: 0.0140
# Epoch 11/50
# 912/912 [==============================] - 1s 556us/step - loss: 1.7134e-04 - mean_absolute_error: 0.0103 - val_loss: 4.8504e-05 - val_mean_absolute_error: 0.0054
# Epoch 12/50
# 912/912 [==============================] - 1s 586us/step - loss: 1.4563e-04 - mean_absolute_error: 0.0095 - val_loss: 9.8390e-05 - val_mean_absolute_error: 0.0085
# Epoch 13/50
# 912/912 [==============================] - 1s 586us/step - loss: 1.6186e-04 - mean_absolute_error: 0.0100 - val_loss: 6.5937e-05 - val_mean_absolute_error: 0.0066
# Epoch 14/50
# 912/912 [==============================] - 1s 640us/step - loss: 1.4223e-04 - mean_absolute_error: 0.0093 - val_loss: 4.2368e-05 - val_mean_absolute_error: 0.0050
# Epoch 15/50
# 912/912 [==============================] - 1s 606us/step - loss: 1.9108e-04 - mean_absolute_error: 0.0109 - val_loss: 4.9428e-05 - val_mean_absolute_error: 0.0055
# Epoch 16/50
# 912/912 [==============================] - 1s 637us/step - loss: 1.7192e-04 - mean_absolute_error: 0.0104 - val_loss: 1.0072e-04 - val_mean_absolute_error: 0.0086
# Epoch 17/50
# 912/912 [==============================] - 1s 578us/step - loss: 1.5689e-04 - mean_absolute_error: 0.0098 - val_loss: 4.3649e-05 - val_mean_absolute_error: 0.0050
# Epoch 18/50
# 912/912 [==============================] - 1s 556us/step - loss: 1.5377e-04 - mean_absolute_error: 0.0098 - val_loss: 5.7484e-05 - val_mean_absolute_error: 0.0060
# Epoch 19/50
# 912/912 [==============================] - 1s 578us/step - loss: 1.4385e-04 - mean_absolute_error: 0.0093 - val_loss: 4.1817e-05 - val_mean_absolute_error: 0.0049
# Epoch 20/50
# 912/912 [==============================] - 1s 566us/step - loss: 1.3851e-04 - mean_absolute_error: 0.0093 - val_loss: 9.2187e-05 - val_mean_absolute_error: 0.0082
# Epoch 21/50
# 912/912 [==============================] - 1s 570us/step - loss: 1.5212e-04 - mean_absolute_error: 0.0098 - val_loss: 5.2955e-05 - val_mean_absolute_error: 0.0056
# Epoch 22/50
# 912/912 [==============================] - 1s 560us/step - loss: 1.5486e-04 - mean_absolute_error: 0.0098 - val_loss: 4.6342e-05 - val_mean_absolute_error: 0.0053
# Epoch 23/50
# 912/912 [==============================] - 0s 545us/step - loss: 1.5699e-04 - mean_absolute_error: 0.0097 - val_loss: 4.2745e-05 - val_mean_absolute_error: 0.0050
# Epoch 24/50
# 912/912 [==============================] - 1s 563us/step - loss: 1.3935e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1756e-04 - val_mean_absolute_error: 0.0094
# Epoch 25/50
# 912/912 [==============================] - 1s 562us/step - loss: 1.4545e-04 - mean_absolute_error: 0.0097 - val_loss: 4.7709e-05 - val_mean_absolute_error: 0.0054
# Epoch 26/50
# 912/912 [==============================] - 1s 565us/step - loss: 1.4909e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2140e-04 - val_mean_absolute_error: 0.0096
# Epoch 27/50
# 912/912 [==============================] - 1s 583us/step - loss: 1.4037e-04 - mean_absolute_error: 0.0094 - val_loss: 3.9650e-05 - val_mean_absolute_error: 0.0048
# Epoch 28/50
# 912/912 [==============================] - 1s 567us/step - loss: 1.4158e-04 - mean_absolute_error: 0.0091 - val_loss: 5.2730e-05 - val_mean_absolute_error: 0.0057
# Epoch 29/50
# 912/912 [==============================] - 1s 570us/step - loss: 1.4580e-04 - mean_absolute_error: 0.0095 - val_loss: 5.3048e-05 - val_mean_absolute_error: 0.0058
# Epoch 30/50
# 912/912 [==============================] - 1s 584us/step - loss: 2.4070e-04 - mean_absolute_error: 0.0124 - val_loss: 4.6162e-05 - val_mean_absolute_error: 0.0054
# Epoch 31/50
# 912/912 [==============================] - 1s 578us/step - loss: 1.4614e-04 - mean_absolute_error: 0.0094 - val_loss: 5.4621e-05 - val_mean_absolute_error: 0.0060
# Epoch 32/50
# 912/912 [==============================] - 1s 577us/step - loss: 1.7783e-04 - mean_absolute_error: 0.0105 - val_loss: 4.0534e-05 - val_mean_absolute_error: 0.0049
# Epoch 33/50
# 912/912 [==============================] - 1s 575us/step - loss: 1.3626e-04 - mean_absolute_error: 0.0093 - val_loss: 3.7243e-05 - val_mean_absolute_error: 0.0045
# Epoch 34/50
# 912/912 [==============================] - 1s 586us/step - loss: 1.3889e-04 - mean_absolute_error: 0.0092 - val_loss: 4.2398e-05 - val_mean_absolute_error: 0.0049
# Epoch 35/50
# 912/912 [==============================] - 1s 604us/step - loss: 1.5691e-04 - mean_absolute_error: 0.0098 - val_loss: 4.4915e-05 - val_mean_absolute_error: 0.0052
# Epoch 36/50
# 912/912 [==============================] - 1s 633us/step - loss: 1.4841e-04 - mean_absolute_error: 0.0097 - val_loss: 4.6130e-05 - val_mean_absolute_error: 0.0052
# Epoch 37/50
# 912/912 [==============================] - 1s 568us/step - loss: 1.8648e-04 - mean_absolute_error: 0.0107 - val_loss: 8.1165e-05 - val_mean_absolute_error: 0.0075
# Epoch 38/50
# 912/912 [==============================] - 1s 569us/step - loss: 1.9952e-04 - mean_absolute_error: 0.0110 - val_loss: 6.2909e-05 - val_mean_absolute_error: 0.0064
# Epoch 39/50
# 912/912 [==============================] - 1s 567us/step - loss: 1.5914e-04 - mean_absolute_error: 0.0101 - val_loss: 9.4032e-05 - val_mean_absolute_error: 0.0081
# Epoch 40/50
# 912/912 [==============================] - 1s 559us/step - loss: 1.7066e-04 - mean_absolute_error: 0.0104 - val_loss: 5.0692e-05 - val_mean_absolute_error: 0.0057
# Epoch 41/50
# 912/912 [==============================] - 1s 578us/step - loss: 1.5708e-04 - mean_absolute_error: 0.0099 - val_loss: 4.5514e-05 - val_mean_absolute_error: 0.0052
# Epoch 42/50
# 912/912 [==============================] - 1s 573us/step - loss: 1.6928e-04 - mean_absolute_error: 0.0103 - val_loss: 4.2986e-05 - val_mean_absolute_error: 0.0050
# Epoch 43/50
# 912/912 [==============================] - 1s 585us/step - loss: 1.8547e-04 - mean_absolute_error: 0.0108 - val_loss: 4.1387e-05 - val_mean_absolute_error: 0.0049
# Epoch 44/50
# 912/912 [==============================] - 1s 569us/step - loss: 1.5014e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0392e-04 - val_mean_absolute_error: 0.0086
# Epoch 45/50
# 912/912 [==============================] - 1s 572us/step - loss: 1.5362e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1894e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 912/912 [==============================] - 1s 567us/step - loss: 1.6898e-04 - mean_absolute_error: 0.0104 - val_loss: 4.6816e-05 - val_mean_absolute_error: 0.0055
# Epoch 47/50
# 912/912 [==============================] - 1s 571us/step - loss: 1.6901e-04 - mean_absolute_error: 0.0101 - val_loss: 8.8534e-05 - val_mean_absolute_error: 0.0078
# Epoch 48/50
# 912/912 [==============================] - 1s 575us/step - loss: 1.4098e-04 - mean_absolute_error: 0.0093 - val_loss: 4.3584e-05 - val_mean_absolute_error: 0.0051
# Epoch 49/50
# 912/912 [==============================] - 1s 586us/step - loss: 1.8685e-04 - mean_absolute_error: 0.0108 - val_loss: 8.4653e-05 - val_mean_absolute_error: 0.0076
# Epoch 50/50
# 912/912 [==============================] - 1s 588us/step - loss: 1.3496e-04 - mean_absolute_error: 0.0091 - val_loss: 4.9913e-05 - val_mean_absolute_error: 0.0057

# %%
print(history1.history)
# Out:
# {'val_loss': [6.215874105453354e-05, 0.00013210830979095008, 4.72864105326093e-05, 4.5515901431036715e-05, 5.708259054923384e-05, 4.406914509285134e-05, 0.0001746095916572455, 4.476541548310855e-05, 6.870471747974914e-05, 0.00023325428129417143, 4.850422503564079e-05, 9.838999116269763e-05, 6.593699337051967e-05, 4.2368245853080615e-05, 4.942804917532829e-05, 0.00010071774562019244, 4.3649113995641406e-05, 5.7484275856070585e-05, 4.18172772309636e-05, 9.218744731309717e-05, 5.29554110024216e-05, 4.63416798948692e-05, 4.274486103686733e-05, 0.00011756418730254185, 4.770852111043317e-05, 0.00012140171769357545, 3.9649642641335484e-05, 5.2729884227432433e-05, 5.3048226742308154e-05, 4.616184952119213e-05, 5.462054121708803e-05, 4.0533574017482336e-05, 3.7243377038499064e-05, 4.239823336648129e-05, 4.4915113790384416e-05, 4.612973916962682e-05, 8.11650162013095e-05, 6.290922298279331e-05, 9.403195905835047e-05, 5.069247800732779e-05, 4.551400579359444e-05, 4.298607570684103e-05, 4.1386786539138094e-05, 0.00010391654729171366, 0.00011893804442732916, 4.681626725541122e-05, 8.853374308616412e-05, 4.358446804260774e-05, 8.465317650469112e-05, 4.991310153377899e-05], 'val_mean_absolute_error': [0.006476097028763568, 0.009923008621716108, 0.005474013578696329, 0.005212909080943123, 0.00605731948477323, 0.005156959862005516, 0.01191203320612673, 0.005120807788411125, 0.006856171224938064, 0.014041586195836302, 0.005419028977878758, 0.008525197427780901, 0.006640493674356429, 0.00499144518961672, 0.0054685549657852925, 0.008612000942230224, 0.005019442370680512, 0.005967602573457312, 0.0049217401957902755, 0.008215477622923304, 0.005648950866011322, 0.005298233032226563, 0.004988357864442419, 0.009433014275597744, 0.005376625451885286, 0.009608017616584653, 0.004777000575769143, 0.005745606148829225, 0.005754332073399278, 0.005387399235709769, 0.006042454086366247, 0.0048663418801104434, 0.004513158954557825, 0.004944258439736288, 0.005227473133900126, 0.005205074880943923, 0.007543998272692571, 0.006371244837026127, 0.008108677824989695, 0.005656215011096391, 0.005242905655845267, 0.0050261325523501535, 0.004915423080569408, 0.008598084332513028, 0.009423469910856153, 0.005500486444254391, 0.00777344000144083, 0.005108913437264865, 0.007631982740808706, 0.0056879973802410186], 'loss': [0.00013244955545432227, 0.0001528326754117172, 0.00016820900342090202, 0.00019315826610086093, 0.00016944572959338283, 0.00018188663798674386, 0.0001647885911281041, 0.00018074275647992627, 0.00016696063884362382, 0.00018573805688279927, 0.0001713412320098366, 0.00014562601267754328, 0.0001618572059669532, 0.00014222845276347934, 0.00019107540222313744, 0.0001719219252934859, 0.00015689130681526047, 0.00015377057474994982, 0.00014384854441966142, 0.00013850890957799397, 0.00015211880925466845, 0.00015485912291823248, 0.00015698730114085615, 0.00013935434796159124, 0.00014544766287272388, 0.00014908519899523655, 0.0001403668284183368, 0.0001415810300769456, 0.00014579583818742417, 0.00024070315460752076, 0.00014613896571079334, 0.00017782792227144615, 0.00013626222885489514, 0.00013889261141517446, 0.00015691145330365224, 0.0001484136981225834, 0.0001864758730669947, 0.00019951966481912358, 0.00015913538497938005, 0.00017065972599339787, 0.00015707878580877534, 0.00016928133347966266, 0.00018547464679342514, 0.00015013747121740475, 0.00015362030012112338, 0.0001689804848227364, 0.00016901045047122527, 0.00014098169802373537, 0.000186853146914744, 0.00013495705117524617], 'mean_absolute_error': [0.008945375876991372, 0.00982289810321833, 0.010178964748455767, 0.011073793856459752, 0.01028889061458278, 0.010548655891366172, 0.010111573691430845, 0.01071462806379586, 0.0102230917923806, 0.010755977250243487, 0.010297342546676335, 0.009522797343762298, 0.010011348742664907, 0.009309971378299227, 0.010883043699881486, 0.010433040461257884, 0.009787448861619882, 0.00978333574899456, 0.00934046127817087, 0.009314777983123796, 0.009821596114259017, 0.0098118907526 ...

# %%
# Plot training & validation accuracy values
plt.plot(history1.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(history.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
model2 = Sequential()
model2.add(CuDNNLSTM(50, input_shape=(None, 1), return_sequences=True))
model2.add(Dropout(0.2))
model2.add(CuDNNLSTM(100, return_sequences=True))
model2.add(Dropout(0.4))
model2.add(CuDNNLSTM(100))
model2.add(Dropout(0.2))
model2.add(Dense(50, activation='tanh'))
model2.add(Dense(20, activation='tanh'))
model2.add(Dense(1, activation='linear'))
model2.compile(loss="mse", optimizer="adam", metrics=['acc'])
print(model2.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_12 (CuDNNLSTM)    (None, None, 50)          10600
# _________________________________________________________________
# dropout_12 (Dropout)         (None, None, 50)          0
# _________________________________________________________________
# cu_dnnlstm_13 (CuDNNLSTM)    (None, None, 100)         60800
# _________________________________________________________________
# dropout_13 (Dropout)         (None, None, 100)         0
# _________________________________________________________________
# cu_dnnlstm_14 (CuDNNLSTM)    (None, 100)               80800
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 158,291
# Trainable params: 158,291
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history2 = model2.fit(x_train, y_train, validation_split=0.25, epochs=3000, batch_size=20, verbose=0)

# %%
plt.figure(figsize=(20, 10))
plt.plot(history2.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
model2.save("model2.h5")

# %% [markdown]
# # 再次训练

# %%
from tensorflow.python.keras.models import load_model
model2_sec = load_model("model2.h5")
history2_sec = model2_sec.fit(x_train, y_train, validation_split=0.25, epochs=500, batch_size=20, verbose=0)

# %%
plt.figure(figsize=(20, 10))
plt.plot(history2_sec.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.ylim(0.0000, 0.0030)
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(all_history2_loss)
plt.title('Model accuracy')
plt.ylabel('val_loss')
plt.ylim(0.0000, 0.0030)
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-7e33b56dbb72> in <module>()
#       1 plt.figure(figsize=(20, 10))
# ----> 2 plt.plot(all_history2_loss)
#       3 plt.title('Model accuracy')
#       4 plt.ylabel('val_loss')
#       5 plt.ylim(0.0000, 0.0030)
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/app/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     351         # downstream.
#     352         if any(v is None for v in tup):
# --> 353             raise ValueError("x, y, and format string must not be None")
#     354
#     355         kw = {}
#
# ValueError: x, y, and format string must not be None

# %%
x_train[0, :, :]

# %%
y_train[0, :]

# %%
model.predict(x_train[0, :, :].reshape(1, 20, 1))
